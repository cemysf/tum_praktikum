# %% [markdown]
# ### Dataset creation

# %%
import pandas as pd
import numpy as np
from sklearn.utils import shuffle

# %% [markdown]
# - load data and labels (normal and different attack types)

# %%
df_data = pd.read_csv("../../datasets/arythmia/arythmia.csv", na_values='?').fillna(0)
df_data = shuffle(df_data)
df_labels = pd.DataFrame(df_data.iloc[:,-1]).astype(str)   
df_data = pd.DataFrame(df_data.iloc[:, :-1]).astype(float)

# %% [markdown]
# - read column names and types

# %%
# col_names=[]
# col_datatypes=[]

# with open("datasets/kddcup/kddcup.names") as file:
#     next(file)    ### skip first line
#     for line in file:
#         name, datatype = line.split(": ")
#         col_names.append(name)
#         col_datatypes.append(datatype.replace(".\n",""))
        
# df_data.columns = col_names
df_labels.columns = ["labels"]

# %%
df_data.head()
# Out:
#         a    b      c     d     e      f      g      h      i     j  ...   \
# 78   56.0  1.0  165.0  73.0  90.0  147.0  388.0  178.0   92.0  88.0  ...
# 139  51.0  1.0  160.0  80.0  85.0  167.0  355.0  151.0  127.0  36.0  ...
# 43   34.0  1.0  165.0  61.0  84.0  152.0  383.0  144.0   71.0  59.0  ...
# 290  60.0  1.0  158.0  75.0  91.0  137.0  387.0  188.0   97.0 -16.0  ...
# 55   72.0  1.0  160.0  70.0  77.0  142.0  392.0  160.0   88.0  30.0  ...
#
#       jj   jk    jl   jm   jn   jo   jp   jq    jr    js
# 78  -1.0 -0.5  14.8 -2.4  0.0  0.0  1.4  2.4  26.8  51.2
# 139  0.2  0.0   6.4 -1.3  0.0  0.0  0.6  1.5  12.0  24.0
# 43  -0.5 -1.0  16.3  0.0  0.0  0.0  0.4 -1.1  37.9  22.1
# 290 -0.2  0.0   7.0 -2.5  0.0  0.0  0.2  0.3  13.1  14.9
# 55  -0.2  0.0   9.0  0.0  0.0  0.0  0.5  2.6  27.0  46.7
#
# [5 rows x 279 columns]

# %% [markdown]
# - check integrity of the data

# %%
print(df_data.isnull().values.any())

print(df_data.isna().values.any())
# Out:
# False
# False

# %% [markdown]
# ### Enumerate labels

# %% [markdown]
# - ### normal samples are named as "anomaly" since they are minority (stated in paper)

# %%
# Considering n labelled data as normal and others as anomaly in thyroid dataset. assigning labels accordingly.
df_data["label"] = np.where(df_labels["labels"].str.contains("3|4|5|7|8|9|14|15", regex=True), 'anomaly', 'normal')
print(df_data['label'])
# Out:
# 78      normal
# 139     normal
# 43      normal
# 290     normal
# 55      normal
# 145     normal
# 40      normal
# 293     normal
# 347     normal
# 414     normal
# 15      normal
# 123     normal
# 205     normal
# 240     normal
# 230     normal
# 64      normal
# 357     normal
# 30      normal
# 408     normal
# 431     normal
# 132     normal
# 162     normal
# 52      normal
# 126     normal
# 281     normal
# 339     normal
# 112     normal
# 157     normal
# 194     normal
# 207    anomaly
#         ...
# 236     normal
# 181     normal
# 403    anomaly
# 231    anomaly
# 60     anomaly
# 446     normal
# 399     normal
# 171     normal
# 160     normal
# 129     normal
# 404     normal
# 61     anomaly
# 291     normal
# 244     normal
# 289     normal
# 200     normal
# 101     normal
# 90      normal
# 368     normal
# 164     normal
# 405     normal
# 299     normal
# 427     normal
# 265     normal
# 441     normal
# 344     normal
# 279     normal
# 303    anomaly
# 87     anomaly
# 197     normal
# Name: label, Length: 452, dtype: object

# %%
### number of normal and abnormal
print("number of normal:", len(np.where(df_data["label"] == 'normal')[0]))
print("number of anomaly:", len(np.where(df_data["label"] == 'anomaly')[0]))
# Out:
# number of normal: 386
# number of anomaly: 66

# %%
## check in which location data is abnormal

np.where(df_data["label"] == 'anomaly')
# Out:
# (array([ 29,  31,  40,  52,  60,  66,  74,  77,  87,  98, 116, 124, 127,
#         132, 139, 140, 145, 152, 153, 158, 160, 164, 169, 175, 188, 189,
#         206, 208, 222, 229, 230, 238, 248, 256, 260, 264, 271, 278, 279,
#         284, 285, 291, 292, 293, 301, 324, 325, 336, 341, 359, 360, 371,
#         376, 387, 388, 399, 401, 402, 408, 415, 424, 425, 426, 433, 449,
#         450]),)

# %%
### looks like working

print(df_data.iloc[100:150, -1])
print(df_labels.iloc[100:150, -1])
# df_data.head()
# Out:
# 147     normal
# 393     normal
# 451     normal
# 36      normal
# 62      normal
# 345     normal
# 365     normal
# 148     normal
# 229     normal
# 391     normal
# 380     normal
# 106     normal
# 155     normal
# 44      normal
# 159     normal
# 343     normal
# 88     anomaly
# 74      normal
# 72      normal
# 38      normal
# 366     normal
# 107     normal
# 324     normal
# 70      normal
# 45     anomaly
# 406     normal
# 17      normal
# 218    anomaly
# 336     normal
# 266     normal
# 14      normal
# 333     normal
# 376    anomaly
# 311     normal
# 51      normal
# 447     normal
# 438     normal
# 255     normal
# 177     normal
# 89     anomaly
# 285    anomaly
# 390     normal
# 7       normal
# 99      normal
# 328     normal
# 251    anomaly
# 402     normal
# 292     normal
# 73      normal
# 120     normal
# Name: label, dtype: object
# 147     1
# 393     1
# 451     1
# 36      1
# 62      1
# 345     1
# 365     1
# 148     1
# 229     1
# 391     1
# 380    16
# 106     6
# 155     1
# 44      1
# 159     1
# 343     6
# 88      9
# 74      1
# 72      1
# 38      1
# 366     2
# 107     1
# 324    10
# 70      6
# 45      4
# 406     1
# 17      1
# 218     3
# 336    10
# 266    10
# 14      1
# 333     1
# 376     8
# 311     1
# 51      1
# 447     1
# 438     1
# 255     1
# 177     1
# 89      9
# 285     3
# 390     1
# 7       1
# 99      1
# 328     1
# 251     4
# 402     1
# 292     1
# 73      1
# 120     1
# Name: labels, dtype: object

# %%
### for each object column in data

cols_toOneHot = df_data.select_dtypes(include='object').columns.tolist()

cols_all = df_data.columns.tolist()
cols_toNormalize = list(set(cols_all) - set(cols_toOneHot))

# %%
print("columns to normalize:\n%s\n" % cols_toNormalize)
print("columns to one-hot:\n%s\n" % cols_toOneHot)
# Out:
# columns to normalize:
# ['ay', 'bu', 'jp', 'jc', 'fp', 'dx', 'cj', 'du', 'm', 'bv', 'y', 'ac', 'cr', 'as', 'dc', 'ao', 'ja', 'jf', 'ha', 'hl', 'fw', 'ck', 'bx', 'fu', 'cd', 'bz', 'ij', 'ik', 'ey', 'gd', 'ab', 'in', 'jh', 'ht', 'ct', 'jb', 'hk', 'ft', 'gm', 'bn', 'cz', 'gz', 'az', 'dp', 'fe', 'hc', 'et', 'ff', 'hy', 'cn', 'i', 'cm', 'eb', 'gw', 'hh', 'ei', 'hu', 'bj', 'fk', 'ap', 'dm', 't', 'aq', 'aa', 'ci', 'ch', 'gc', 's', 'hj', 'b', 'hd', 'gk', 'bw', 'gq', 'br', 'df', 'ee', 'aw', 'hf', 'cp', 'ia', 'ec', 'jd', 'fo', 'ix', 'ce', 'ge', 'fv', 'a', 'hq', 'iv', 'hi', 'gt', 'ah', 'gl', 'iq', 'bb', 'w', 'fl', 'f', 'gg', 'ew', 'cg', 'ho', 'cf', 'jk', 'dq', 'ex', 'gv', 'ea', 'ji', 'cx', 'ga', 'gj', 'ak', 'cy', 'p', 'em', 'io', 'fg', 'e', 'bf', 'dn', 'eq', 'di', 'hn', 'el', 'dy', 'l', 'av', 'n', 'fi', 'v', 'je', 'gx', 'u', 'gu', 'fa', 'he', 'fc', 'bi', 'jm', 'cc', 'fx', 'bl', 'es', 'fr', 'eh', 'cb', 'fj', 'bh', 'eo', 'if', 'gr', 'h', 'af', 'fq', 'ae', 'hb', 'ax', 'dg', 'bs', 'hz', 'am', 'go', 'it', 'aj', 'cs', 'ir', 'gh', 'r', 'cq', 'hg', 'en', 'hx', 'iu', 'jl', 'k', 'ic', 'cv', 'dv', 'x', 'fn', 'ej', 'da', 'cl', 'eu', 'ar', 'ed', 'bp', 'dl', 'ek', 'hr', 'fb', 'hp', 'iz', 'bt', 'gy', 'be', 'ds', 'db', 'ig', 'at', 'jj', 'hw', 'de', 'bq', 'bm', 'ai', 'gp', 'bk', 'cu', 'fz', 'ba', 'gs', 'il', 'dk', 'al', 'ep', 'z', 'q', 'ip', 'g', 'ad', 'jr', 'hv', 'c', 'id', 'ev', 'gn', 'an', 'er', 'ag', 'fy', 'gf', 'ie', 'eg', 'ez', 'bg', 'by', 'ib', 'bd', 'dd', 'au', 'hs', 'd', 'ca', 'dw', 'is', 'dr', 'jo', 'jq', 'jn', 'bo', 'gi', 'gb', 'fd', 'dj', 'fs', 'iw', 'fm', 'hm', 'iy', 'ii', 'j', 'co', 'dh', 'dz', 'ih', 'im', 'o', 'ef', 'cw', 'do', 'js', 'bc', 'fh', 'jg', 'dt']
#
# columns to one-hot:
# ['label']

# %%
len(cols_toNormalize)
# Out:
# 279

# %% [markdown]
# ### Dataset preprocessing in numerical columns

# %%
print(df_data.aa.dtype)
# Out:
# float64

# %%
def checkStats(df_data):
    i=0
    for col in df_data.columns.tolist():
            
        if col in cols_toOneHot:    ### skip if column is not numerical  ### TODO: check column type??
            i += 1
            continue

        min_ = df_data[col].values.min()
        max_ = df_data[col].values.max()
        std_ = df_data[col].values.std()

        print("column:%d min:%f max:%f std:%f" % (i, min_, max_, std_))
        i += 1

# %%
## before normalization
df_data = df_data
checkStats(df_data)
# Out:
# column:0 min:0.000000 max:83.000000 std:16.448406
# column:1 min:0.000000 max:1.000000 std:0.497404
# column:2 min:105.000000 max:780.000000 std:37.129200
# column:3 min:6.000000 max:176.000000 std:16.572440
# column:4 min:55.000000 max:188.000000 std:15.347388
# column:5 min:0.000000 max:524.000000 std:44.792651
# column:6 min:232.000000 max:509.000000 std:33.348470
# column:7 min:108.000000 max:381.000000 std:35.593633
# column:8 min:0.000000 max:205.000000 std:25.798058
# column:9 min:-172.000000 max:169.000000 std:45.381150
# column:10 min:-177.000000 max:179.000000 std:57.477332
# column:11 min:-170.000000 max:176.000000 std:30.465943
# column:12 min:-135.000000 max:166.000000 std:35.982320
# column:13 min:-179.000000 max:178.000000 std:52.071135
# column:14 min:0.000000 max:163.000000 std:14.275317
# column:15 min:0.000000 max:88.000000 std:10.638214
# column:16 min:0.000000 max:156.000000 std:18.229702
# column:17 min:0.000000 max:88.000000 std:20.518993
# column:18 min:0.000000 max:24.000000 std:1.567746
# column:19 min:0.000000 max:0.000000 std:0.000000
# column:20 min:0.000000 max:100.000000 std:10.035273
# column:21 min:0.000000 max:1.000000 std:0.046984
# column:22 min:0.000000 max:1.000000 std:0.104592
# column:23 min:0.000000 max:1.000000 std:0.104592
# column:24 min:0.000000 max:1.000000 std:0.066372
# column:25 min:0.000000 max:1.000000 std:0.066372
# column:26 min:0.000000 max:1.000000 std:0.093655
# column:27 min:0.000000 max:76.000000 std:11.208261
# column:28 min:0.000000 max:132.000000 std:17.229123
# column:29 min:0.000000 max:92.000000 std:21.037740
# column:30 min:0.000000 max:36.000000 std:3.089738
# column:31 min:0.000000 max:56.000000 std:2.689610
# column:32 min:0.000000 max:76.000000 std:9.614298
# column:33 min:0.000000 max:1.000000 std:0.131855
# column:34 min:0.000000 max:1.000000 std:0.167134
# column:35 min:0.000000 max:1.000000 std:0.046984
# column:36 min:0.000000 max:1.000000 std:0.066372
# column:37 min:0.000000 max:1.000000 std:0.066372
# column:38 min:0.000000 max:1.000000 std:0.123478
# column:39 min:0.000000 max:92.000000 std:21.882211
# column:40 min:0.000000 max:116.000000 std:23.080460
# column:41 min:0.000000 max:132.000000 std:25.337350
# column:42 min:0.000000 max:64.000000 std:9.202621
# column:43 min:0.000000 max:44.000000 std:3.120771
# column:44 min:0.000000 max:92.000000 std:18.339529
# column:45 min:0.000000 max:1.000000 std:0.046984
# column:46 min:0.000000 max:1.000000 std:0.184784
# column:47 min:0.000000 max:1.000000 std:0.046984
# column:48 min:0.000000 max:1.000000 std:0.131855
# column:49 min:0.000000 max:1.000000 std:0.104592
# column:50 min:0.000000 max:1.000000 std:0.066372
# column:51 min:0.000000 max:136.000000 std:24.786187
# column:52 min:0.000000 max:80.000000 std:17.369713
# column:53 min:0.000000 max:80.000000 std:18.345581
# column:54 min:0.000000 max:84.000000 std:10.308284
# column:55 min:0.000000 max:32.000000 std:1.503487
# column:56 min:0.000000 max:92.000000 std:27.917866
# column:57 min:0.000000 max:1.000000 std:0.104592
# column:58 min:0.000000 max:1.000000 std:0.066372
# column:59 min:0.000000 max:1.000000 std:0.066372
# column:60 min:0.000000 max:1.000000 std:0.066372
# column:61 min:0.000000 max:1.000000 std:0.066372
# column:62 min:0.000000 max:1.000000 std:0.093655
# column:63 min:0.000000 max:88.000000 std:17.178783
# column:64 min:0.000000 max:148.000000 std:22.606212
# column:65 min:0.000000 max:92.000000 std:22.974617
# column:66 min:0.000000 max:44.000000 std:5.245392
# column:67 min:0.000000 max:0.000000 std:0.000000
# column:68 min:0.000000 max:96.000000 std:15.479581
# column:69 min:0.000000 max:0.000000 std:0.000000
# column:70 min:0.000000 max:1.000000 std:0.131855
# column:71 min:0.000000 max:1.000000 std:0.046984
# column:72 min:0.000000 max:1.000000 std:0.046984
# column:73 min:0.000000 max:1.000000 std:0.081198
# column:74 min:0.000000 max:1.000000 std:0.046984
# column:75 min:0.000000 max:88.000000 std:15.341884
# column:76 min:0.000000 max:128.000000 std:20.185265
# column:77 min:0.000000 max:120.000000 std:23.166828
# column:78 min:0.000000 max:44.000000 std:4.670580
# column:79 min:0.000000 max:44.000000 std:2.788201
# column:80 min:0.000000 max:80.000000 std:13.014038
# column:81 min:0.000000 max:1.000000 std:0.066372
# column:82 min:0.000000 max:1.000000 std:0.154091
# column:83 min:0.000000 max:0.000000 std:0.000000
# column:84 min:0.000000 max:1.000000 std:0.046984
# column:85 min:0.000000 max:1.000000 std:0.046984
# column:86 min:0.000000 max:1.000000 std:0.046984
# column:87 min:0.000000 max:140.000000 std:26.798342
# column:88 min:0.000000 max:216.000000 std:16.399097
# column:89 min:0.000000 max:116.000000 std:23.839111
# column:90 min:0.000000 max:80.000000 std:12.566281
# column:91 min:0.000000 max:28.000000 std:1.535723
# column:92 min:0.000000 max:116.000000 std:19.148349
# column:93 min:0.000000 max:1.000000 std:0.081198
# column:94 min:0.000000 max:1.000000 std:0.123478
# column:95 min:0.000000 max:1.000000 std:0.093655
# column:96 min:0.000000 max:1.000000 std:0.093655
# column:97 min:0.000000 max:1.000000 std:0.104592
# column:98 min:0.000000 max:1.000000 std:0.147086
# column:99 min:0.000000 max:132.000000 std:20.960959
# column:100 min:0.000000 max:216.000000 std:16.255392
# column:101 min:0.000000 max:108.000000 std:17.504201
# column:102 min:0.000000 max:72.000000 std:8.378152
# column:103 min:0.000000 max:32.000000 std:2.250782
# column:104 min:0.000000 max:96.000000 std:13.072768
# column:105 min:0.000000 max:1.000000 std:0.093655
# column:106 min:0.000000 max:1.000000 std:0.093655
# column:107 min:0.000000 max:1.000000 std:0.114447
# column:108 min:0.000000 max:1.000000 std:0.093655
# column:109 min:0.000000 max:1.000000 std:0.093655
# column:110 min:0.000000 max:1.000000 std:0.131855
# column:111 min:0.000000 max:96.000000 std:16.306820
# column:112 min:0.000000 max:132.000000 std:13.565988
# column:113 min:0.000000 max:112.000000 std:16.406488
# column:114 min:0.000000 max:76.000000 std:5.250428
# column:115 min:0.000000 max:36.000000 std:2.030757
# column:116 min:0.000000 max:88.000000 std:10.138874
# column:117 min:0.000000 max:1.000000 std:0.154091
# column:118 min:0.000000 max:1.000000 std:0.066372
# column:119 min:0.000000 max:1.000000 std:0.081198
# column:120 min:0.000000 max:1.000000 std:0.093655
# column:121 min:0.000000 max:1.000000 std:0.081198
# column:122 min:0.000000 max:1.000000 std:0.104592
# column:123 min:0.000000 max:88.000000 std:11.517800
# column:124 min:0.000000 max:92.000000 std:10.371542
# column:125 min:0.000000 max:124.000000 std:16.933094
# column:126 min:0.000000 max:24.000000 std:2.970645
# column:127 min:0.000000 max:40.000000 std:2.022584
# column:128 min:0.000000 max:60.000000 std:7.766948
# column:129 min:0.000000 max:1.000000 std:0.066372
# column:130 min:0.000000 max:1.000000 std:0.114447
# column:131 min:0.000000 max:0.000000 std:0.000000
# column:132 min:0.000000 max:0.000000 std:0.000000
# column:133 min:0.000000 max:1.000000 std:0.066372
# column:134 min:0.000000 max:1.000000 std:0.131855
# column:135 min:0.000000 max:88.000000 std:10.758278
# column:136 min:0.000000 max:136.000000 std:11.984546
# column:137 min:0.000000 max:120.000000 std:17.290767
# column:138 min:0.000000 max:60.000000 std:3.235503
# column:139 min:0.000000 max:0.000000 std:0.000000
# column:140 min:0.000000 max:132.000000 std:10.451683
# column:141 min:0.000000 max:0.000000 std:0.000000
# column:142 min:0.000000 max:1.000000 std:0.081198
# column:143 min:0.000000 max:0.000000 std:0.000000
# column:144 min:0.000000 max:1.000000 std:0.046984
# column:145 min:0.000000 max:0.000000 std:0.000000
# column:146 min:0.000000 max:1.000000 std:0.081198
# column:147 min:0.000000 max:88.000000 std:11.080533
# column:148 min:0.000000 max:148.000000 std:14.998982
# column:149 min:0.000000 max:108.000000 std:22.276055
# column:150 min:0.000000 max:28.000000 std:1.865956
# column:151 min:0.000000 max:0.000000 std:0.000000
# column:152 min:0.000000 max:104.000000 std:10.260676
# column:153 min:0.000000 max:1.000000 std:0.046984
# column:154 min:0.000000 max:1.000000 std:0.046984
# column:155 min:0.000000 max:1.000000 std:0.066372
# column:156 min:0.000000 max:0.000000 std:0.000000
# column:157 min:0.000000 max:0.000000 std:0.000000
# column:158 min:0.000000 max:1.000000 std:0.104592
# column:159 min:-9.000000 max:1.400000 std:0.623609
# column:160 min:-2.700000 max:0.000000 std:0.395990
# column:161 min:0.000000 max:19.900000 std:2.800171
# column:162 min:-13.800000 max:0.000000 std:1.480778
# column:163 min:0.000000 max:1.900000 std:0.094877
# column:164 min:0.000000 max:0.000000 std:0.000000
# column:165 min:-1.500000 max:1.700000 std:0.346622
# column:166 min:-8.700000 max:3.700000 std:1.211946
# column:167 min:-33.300000 max:155.200000 std:13.178315
# column:168 min:-38.800000 max:74.300000 std:13.340714
# column:169 min:-3.900000 max:1.900000 std:0.523002
# column:170 min:-3.400000 max:0.000000 std:0.555600
# column:171 min:0.000000 max:19.200000 std:3.486454
# column:172 min:-16.500000 max:0.000000 std:1.809051
# column:173 min:0.000000 max:3.200000 std:0.176047
# column:174 min:-1.500000 max:0.000000 std:0.090156
# column:175 min:-1.500000 max:3.400000 std:0.552718
# column:176 min:-4.400000 max:7.200000 std:1.340608
# column:177 min:-43.000000 max:64.600000 std:14.288796
# column:178 min:-38.500000 max:87.100000 std:18.448700
# column:179 min:-1.700000 max:5.100000 std:0.546669
# column:180 min:-16.500000 max:0.000000 std:1.919355
# column:181 min:0.000000 max:21.700000 std:3.445313
# column:182 min:-16.300000 max:0.000000 std:2.849865
# column:183 min:0.000000 max:14.900000 std:0.877878
# column:184 min:-1.700000 max:0.000000 std:0.130013
# column:185 min:-2.800000 max:2.200000 std:0.546235
# column:186 min:-7.000000 max:7.100000 std:1.174269
# column:187 min:-74.000000 max:66.700000 std:16.679165
# column:188 min:-58.600000 max:95.800000 std:18.367155
# column:189 min:-1.900000 max:6.400000 std:0.521541
# column:190 min:-16.000000 max:0.000000 std:3.043539
# column:191 min:0.000000 max:11.800000 std:1.174715
# column:192 min:-12.800000 max:0.000000 std:2.796128
# column:193 min:0.000000 max:3.500000 std:0.438233
# column:194 min:-0.400000 max:0.000000 std:0.018794
# column:195 min:-2.300000 max:1.300000 std:0.392956
# column:196 min:-3.900000 max:6.400000 std:1.114459
# column:197 min:-96.500000 max:26.300000 std:10.877191
# column:198 min:-82.700000 max:10.700000 std:12.780125
# column:199 min:-7.100000 max:2.600000 std:0.539045
# column:200 min:-8.700000 max:0.000000 std:0.990936
# column:201 min:0.000000 max:15.600000 std:2.866464
# column:202 min:-13.300000 max:0.000000 std:1.994712
# column:203 min:0.000000 max:2.300000 std:0.193553
# column:204 min:0.000000 max:0.000000 std:0.000000
# column:205 min:-1.400000 max:2.000000 std:0.410258
# column:206 min:-6.700000 max:5.100000 std:0.960951
# column:207 min:-38.700000 max:115.400000 std:13.155413
# column:208 min:-42.100000 max:46.100000 std:12.680469
# column:209 min:-1.700000 max:2.500000 std:0.446990
# column:210 min:-6.800000 max:0.000000 std:0.921360
# column:211 min:0.000000 max:19.900000 std:3.516410
# column:212 min:-15.400000 max:0.000000 std:2.049976
# column:213 min:0.000000 max:9.100000 std:0.488834
# column:214 min:-4.500000 max:0.000000 std:0.265170
# column:215 min:-2.100000 max:2.700000 std:0.504218
# column:216 min:-5.500000 max:7.000000 std:1.052264
# column:217 min:-44.000000 max:64.200000 std:14.512303
# column:218 min:-49.400000 max:69.100000 std:16.756737
# column:219 min:-4.500000 max:16.600000 std:1.054396
# column:220 min:-19.100000 max:0.000000 std:3.309916
# column:221 min:0.000000 max:26.000000 std:2.224118
# column:222 min:-37.800000 max:0.000000 std:4.877168
# column:223 min:0.000000 max:19.200000 std:1.488673
# column:224 min:-2.900000 max:0.000000 std:0.141301
# column:225 min:-3.500000 max:1.800000 std:0.574261
# column:226 min:-4.900000 max:16.700000 std:1.781208
# column:227 min:-216.000000 max:268.900000 std:23.688759
# column:228 min:-107.200000 max:247.100000 std:20.990830
# column:229 min:-4.100000 max:10.000000 std:1.176411
# column:230 min:-30.300000 max:0.000000 std:3.759689
# column:231 min:0.000000 max:28.500000 std:3.342472
# column:232 min:-43.300000 max:0.000000 std:5.883525
# column:233 min:0.000000 max:14.900000 std:0.970612
# column:234 min:-4.000000 max:0.000000 std:0.218124
# column:235 min:-2.300000 max:3.300000 std:0.491676
# column:236 min:-8.600000 max:13.200000 std:2.407044
# column:237 min:-195.300000 max:133.900000 std:25.631400
# column:238 min:-95.100000 max:123.600000 std:26.626951
# column:239 min:-3.300000 max:15.100000 std:1.442574
# column:240 min:-32.900000 max:0.000000 std:3.410306
# column:241 min:0.000000 max:28.400000 std:5.273876
# column:242 min:-48.400000 max:0.000000 std:7.058747
# column:243 min:0.000000 max:7.000000 std:0.389971
# column:244 min:-5.600000 max:0.000000 std:0.264105
# column:245 min:-3.100000 max:2.500000 std:0.548381
# column:246 min:-11.800000 max:18.800000 std:2.987499
# column:247 min:-242.400000 max:165.400000 std:32.121416
# column:248 min:-146.200000 max:137.800000 std:37.320936
# column:249 min:-3.200000 max:9.700000 std:1.014442
# column:250 min:-20.400000 max:0.000000 std:1.756598
# column:251 min:0.000000 max:36.400000 std:5.910842
# column:252 min:-42.900000 max:0.000000 std:5.055870
# column:253 min:0.000000 max:2.400000 std:0.166579
# column:254 min:-0.900000 max:0.000000 std:0.046236
# column:255 min:-2.600000 max:2.800000 std:0.426469
# column:256 min:-8.200000 max:15.600000 std:2.427087
# column:257 min:-124.800000 max:103.400000 std:25.046942
# column:258 min:-161.400000 max:182.300000 std:34.323633
# column:259 min:-4.800000 max:3.400000 std:0.674313
# column:260 min:-14.200000 max:0.000000 std:0.991374
# column:261 min:0.000000 max:29.500000 std:4.788350
# column:262 min:-30.800000 max:0.000000 std:2.847478
# column:263 min:0.000000 max:5.800000 std:0.275602
# column:264 min:0.000000 max:0.000000 std:0.000000
# column:265 min:-0.900000 max:2.800000 std:0.370138
# column:266 min:-5.000000 max:8.300000 std:1.706299
# column:267 min:-56.800000 max:82.100000 std:16.427270
# column:268 min:-63.600000 max:127.900000 std:24.394613
# column:269 min:-5.600000 max:2.700000 std:0.602883
# column:270 min:-4.100000 max:0.000000 std:0.548268
# column:271 min:0.000000 max:23.600000 std:3.469018
# column:272 min:-28.600000 max:0.000000 std:2.000213
# column:273 min:0.000000 max:0.800000 std:0.050063
# column:274 min:0.000000 max:0.000000 std:0.000000
# column:275 min:-0.800000 max:2.400000 std:0.347146
# column:276 min:-6.000000 max:6.000000 std:1.424473
# column:277 min:-44.200000 max:88.800000 std:13.488976
# column:278 min:-38.600000 max:115.900000 std:18.473458

# %%
### normalization

### min substr and max-min div

def normalise(df_data, cols_toNormalize):
    for col in cols_toNormalize:
            
        min = df_data[col].min()
        max = df_data[col].max()

        if max - min == 0:
            continue

        df_data[col] = (df_data[col] - min) / (max - min)
    
    return df_data



"""
### mean substr and std dev div
for col in cols_toNormalize:
    mean = df_data[col].mean()
    std = df_data[col].std()
    
    if mean == 0 or std == 0:     ### columns 'num_outbound_cmds', 'is_host_login' has zero mean and std dev!!!
        continue
    
    df_data[col] = (df_data[col] - mean) / std
"""
# Out:
# "\n### mean substr and std dev div\nfor col in cols_toNormalize:\n    mean = df_data[col].mean()\n    std = df_data[col].std()\n    \n    if mean == 0 or std == 0:     ### columns 'num_outbound_cmds', 'is_host_login' has zero mean and std dev!!!\n        continue\n    \n    df_data[col] = (df_data[col] - mean) / std\n"

# %%
# ### Skipping normalisation for thyroid dataset. Added by Jyotirmay
df_data=normalise(df_data, cols_toNormalize)
checkStats(df_data)
# Out:
# column:0 min:0.000000 max:1.000000 std:0.198174
# column:1 min:0.000000 max:1.000000 std:0.497404
# column:2 min:0.000000 max:1.000000 std:0.055006
# column:3 min:0.000000 max:1.000000 std:0.097485
# column:4 min:0.000000 max:1.000000 std:0.115394
# column:5 min:0.000000 max:1.000000 std:0.085482
# column:6 min:0.000000 max:1.000000 std:0.120392
# column:7 min:0.000000 max:1.000000 std:0.130380
# column:8 min:0.000000 max:1.000000 std:0.125844
# column:9 min:0.000000 max:1.000000 std:0.133083
# column:10 min:0.000000 max:1.000000 std:0.161453
# column:11 min:0.000000 max:1.000000 std:0.088052
# column:12 min:0.000000 max:1.000000 std:0.119543
# column:13 min:0.000000 max:1.000000 std:0.145858
# column:14 min:0.000000 max:1.000000 std:0.087579
# column:15 min:0.000000 max:1.000000 std:0.120889
# column:16 min:0.000000 max:1.000000 std:0.116857
# column:17 min:0.000000 max:1.000000 std:0.233170
# column:18 min:0.000000 max:1.000000 std:0.065323
# column:19 min:0.000000 max:0.000000 std:0.000000
# column:20 min:0.000000 max:1.000000 std:0.100353
# column:21 min:0.000000 max:1.000000 std:0.046984
# column:22 min:0.000000 max:1.000000 std:0.104592
# column:23 min:0.000000 max:1.000000 std:0.104592
# column:24 min:0.000000 max:1.000000 std:0.066372
# column:25 min:0.000000 max:1.000000 std:0.066372
# column:26 min:0.000000 max:1.000000 std:0.093655
# column:27 min:0.000000 max:1.000000 std:0.147477
# column:28 min:0.000000 max:1.000000 std:0.130524
# column:29 min:0.000000 max:1.000000 std:0.228671
# column:30 min:0.000000 max:1.000000 std:0.085826
# column:31 min:0.000000 max:1.000000 std:0.048029
# column:32 min:0.000000 max:1.000000 std:0.126504
# column:33 min:0.000000 max:1.000000 std:0.131855
# column:34 min:0.000000 max:1.000000 std:0.167134
# column:35 min:0.000000 max:1.000000 std:0.046984
# column:36 min:0.000000 max:1.000000 std:0.066372
# column:37 min:0.000000 max:1.000000 std:0.066372
# column:38 min:0.000000 max:1.000000 std:0.123478
# column:39 min:0.000000 max:1.000000 std:0.237850
# column:40 min:0.000000 max:1.000000 std:0.198969
# column:41 min:0.000000 max:1.000000 std:0.191950
# column:42 min:0.000000 max:1.000000 std:0.143791
# column:43 min:0.000000 max:1.000000 std:0.070927
# column:44 min:0.000000 max:1.000000 std:0.199343
# column:45 min:0.000000 max:1.000000 std:0.046984
# column:46 min:0.000000 max:1.000000 std:0.184784
# column:47 min:0.000000 max:1.000000 std:0.046984
# column:48 min:0.000000 max:1.000000 std:0.131855
# column:49 min:0.000000 max:1.000000 std:0.104592
# column:50 min:0.000000 max:1.000000 std:0.066372
# column:51 min:0.000000 max:1.000000 std:0.182251
# column:52 min:0.000000 max:1.000000 std:0.217121
# column:53 min:0.000000 max:1.000000 std:0.229320
# column:54 min:0.000000 max:1.000000 std:0.122718
# column:55 min:0.000000 max:1.000000 std:0.046984
# column:56 min:0.000000 max:1.000000 std:0.303455
# column:57 min:0.000000 max:1.000000 std:0.104592
# column:58 min:0.000000 max:1.000000 std:0.066372
# column:59 min:0.000000 max:1.000000 std:0.066372
# column:60 min:0.000000 max:1.000000 std:0.066372
# column:61 min:0.000000 max:1.000000 std:0.066372
# column:62 min:0.000000 max:1.000000 std:0.093655
# column:63 min:0.000000 max:1.000000 std:0.195213
# column:64 min:0.000000 max:1.000000 std:0.152745
# column:65 min:0.000000 max:1.000000 std:0.249724
# column:66 min:0.000000 max:1.000000 std:0.119213
# column:67 min:0.000000 max:0.000000 std:0.000000
# column:68 min:0.000000 max:1.000000 std:0.161246
# column:69 min:0.000000 max:0.000000 std:0.000000
# column:70 min:0.000000 max:1.000000 std:0.131855
# column:71 min:0.000000 max:1.000000 std:0.046984
# column:72 min:0.000000 max:1.000000 std:0.046984
# column:73 min:0.000000 max:1.000000 std:0.081198
# column:74 min:0.000000 max:1.000000 std:0.046984
# column:75 min:0.000000 max:1.000000 std:0.174340
# column:76 min:0.000000 max:1.000000 std:0.157697
# column:77 min:0.000000 max:1.000000 std:0.193057
# column:78 min:0.000000 max:1.000000 std:0.106150
# column:79 min:0.000000 max:1.000000 std:0.063368
# column:80 min:0.000000 max:1.000000 std:0.162675
# column:81 min:0.000000 max:1.000000 std:0.066372
# column:82 min:0.000000 max:1.000000 std:0.154091
# column:83 min:0.000000 max:0.000000 std:0.000000
# column:84 min:0.000000 max:1.000000 std:0.046984
# column:85 min:0.000000 max:1.000000 std:0.046984
# column:86 min:0.000000 max:1.000000 std:0.046984
# column:87 min:0.000000 max:1.000000 std:0.191417
# column:88 min:0.000000 max:1.000000 std:0.075922
# column:89 min:0.000000 max:1.000000 std:0.205510
# column:90 min:0.000000 max:1.000000 std:0.157079
# column:91 min:0.000000 max:1.000000 std:0.054847
# column:92 min:0.000000 max:1.000000 std:0.165072
# column:93 min:0.000000 max:1.000000 std:0.081198
# column:94 min:0.000000 max:1.000000 std:0.123478
# column:95 min:0.000000 max:1.000000 std:0.093655
# column:96 min:0.000000 max:1.000000 std:0.093655
# column:97 min:0.000000 max:1.000000 std:0.104592
# column:98 min:0.000000 max:1.000000 std:0.147086
# column:99 min:0.000000 max:1.000000 std:0.158795
# column:100 min:0.000000 max:1.000000 std:0.075256
# column:101 min:0.000000 max:1.000000 std:0.162076
# column:102 min:0.000000 max:1.000000 std:0.116363
# column:103 min:0.000000 max:1.000000 std:0.070337
# column:104 min:0.000000 max:1.000000 std:0.136175
# column:105 min:0.000000 max:1.000000 std:0.093655
# column:106 min:0.000000 max:1.000000 std:0.093655
# column:107 min:0.000000 max:1.000000 std:0.114447
# column:108 min:0.000000 max:1.000000 std:0.093655
# column:109 min:0.000000 max:1.000000 std:0.093655
# column:110 min:0.000000 max:1.000000 std:0.131855
# column:111 min:0.000000 max:1.000000 std:0.169863
# column:112 min:0.000000 max:1.000000 std:0.102773
# column:113 min:0.000000 max:1.000000 std:0.146486
# column:114 min:0.000000 max:1.000000 std:0.069085
# column:115 min:0.000000 max:1.000000 std:0.056410
# column:116 min:0.000000 max:1.000000 std:0.115214
# column:117 min:0.000000 max:1.000000 std:0.154091
# column:118 min:0.000000 max:1.000000 std:0.066372
# column:119 min:0.000000 max:1.000000 std:0.081198
# column:120 min:0.000000 max:1.000000 std:0.093655
# column:121 min:0.000000 max:1.000000 std:0.081198
# column:122 min:0.000000 max:1.000000 std:0.104592
# column:123 min:0.000000 max:1.000000 std:0.130884
# column:124 min:0.000000 max:1.000000 std:0.112734
# column:125 min:0.000000 max:1.000000 std:0.136557
# column:126 min:0.000000 max:1.000000 std:0.123777
# column:127 min:0.000000 max:1.000000 std:0.050565
# column:128 min:0.000000 max:1.000000 std:0.129449
# column:129 min:0.000000 max:1.000000 std:0.066372
# column:130 min:0.000000 max:1.000000 std:0.114447
# column:131 min:0.000000 max:0.000000 std:0.000000
# column:132 min:0.000000 max:0.000000 std:0.000000
# column:133 min:0.000000 max:1.000000 std:0.066372
# column:134 min:0.000000 max:1.000000 std:0.131855
# column:135 min:0.000000 max:1.000000 std:0.122253
# column:136 min:0.000000 max:1.000000 std:0.088122
# column:137 min:0.000000 max:1.000000 std:0.144090
# column:138 min:0.000000 max:1.000000 std:0.053925
# column:139 min:0.000000 max:0.000000 std:0.000000
# column:140 min:0.000000 max:1.000000 std:0.079179
# column:141 min:0.000000 max:0.000000 std:0.000000
# column:142 min:0.000000 max:1.000000 std:0.081198
# column:143 min:0.000000 max:0.000000 std:0.000000
# column:144 min:0.000000 max:1.000000 std:0.046984
# column:145 min:0.000000 max:0.000000 std:0.000000
# column:146 min:0.000000 max:1.000000 std:0.081198
# column:147 min:0.000000 max:1.000000 std:0.125915
# column:148 min:0.000000 max:1.000000 std:0.101344
# column:149 min:0.000000 max:1.000000 std:0.206260
# column:150 min:0.000000 max:1.000000 std:0.066641
# column:151 min:0.000000 max:0.000000 std:0.000000
# column:152 min:0.000000 max:1.000000 std:0.098660
# column:153 min:0.000000 max:1.000000 std:0.046984
# column:154 min:0.000000 max:1.000000 std:0.046984
# column:155 min:0.000000 max:1.000000 std:0.066372
# column:156 min:0.000000 max:0.000000 std:0.000000
# column:157 min:0.000000 max:0.000000 std:0.000000
# column:158 min:0.000000 max:1.000000 std:0.104592
# column:159 min:0.000000 max:1.000000 std:0.059962
# column:160 min:0.000000 max:1.000000 std:0.146663
# column:161 min:0.000000 max:1.000000 std:0.140712
# column:162 min:0.000000 max:1.000000 std:0.107303
# column:163 min:0.000000 max:1.000000 std:0.049935
# column:164 min:0.000000 max:0.000000 std:0.000000
# column:165 min:0.000000 max:1.000000 std:0.108319
# column:166 min:0.000000 max:1.000000 std:0.097738
# column:167 min:0.000000 max:1.000000 std:0.069911
# column:168 min:0.000000 max:1.000000 std:0.117955
# column:169 min:0.000000 max:1.000000 std:0.090173
# column:170 min:0.000000 max:1.000000 std:0.163412
# column:171 min:0.000000 max:1.000000 std:0.181586
# column:172 min:0.000000 max:1.000000 std:0.109639
# column:173 min:0.000000 max:1.000000 std:0.055015
# column:174 min:0.000000 max:1.000000 std:0.060104
# column:175 min:0.000000 max:1.000000 std:0.112800
# column:176 min:0.000000 max:1.000000 std:0.115570
# column:177 min:0.000000 max:1.000000 std:0.132795
# column:178 min:0.000000 max:1.000000 std:0.146885
# column:179 min:0.000000 max:1.000000 std:0.080392
# column:180 min:0.000000 max:1.000000 std:0.116325
# column:181 min:0.000000 max:1.000000 std:0.158770
# column:182 min:0.000000 max:1.000000 std:0.174838
# column:183 min:0.000000 max:1.000000 std:0.058918
# column:184 min:0.000000 max:1.000000 std:0.076478
# column:185 min:0.000000 max:1.000000 std:0.109247
# column:186 min:0.000000 max:1.000000 std:0.083281
# column:187 min:0.000000 max:1.000000 std:0.118544
# column:188 min:0.000000 max:1.000000 std:0.118958
# column:189 min:0.000000 max:1.000000 std:0.062836
# column:190 min:0.000000 max:1.000000 std:0.190221
# column:191 min:0.000000 max:1.000000 std:0.099552
# column:192 min:0.000000 max:1.000000 std:0.218447
# column:193 min:0.000000 max:1.000000 std:0.125209
# column:194 min:0.000000 max:1.000000 std:0.046984
# column:195 min:0.000000 max:1.000000 std:0.109155
# column:196 min:0.000000 max:1.000000 std:0.108200
# column:197 min:0.000000 max:1.000000 std:0.088576
# column:198 min:0.000000 max:1.000000 std:0.136832
# column:199 min:0.000000 max:1.000000 std:0.055572
# column:200 min:0.000000 max:1.000000 std:0.113901
# column:201 min:0.000000 max:1.000000 std:0.183748
# column:202 min:0.000000 max:1.000000 std:0.149978
# column:203 min:0.000000 max:1.000000 std:0.084153
# column:204 min:0.000000 max:0.000000 std:0.000000
# column:205 min:0.000000 max:1.000000 std:0.120664
# column:206 min:0.000000 max:1.000000 std:0.081437
# column:207 min:0.000000 max:1.000000 std:0.085369
# column:208 min:0.000000 max:1.000000 std:0.143769
# column:209 min:0.000000 max:1.000000 std:0.106426
# column:210 min:0.000000 max:1.000000 std:0.135494
# column:211 min:0.000000 max:1.000000 std:0.176704
# column:212 min:0.000000 max:1.000000 std:0.133115
# column:213 min:0.000000 max:1.000000 std:0.053718
# column:214 min:0.000000 max:1.000000 std:0.058927
# column:215 min:0.000000 max:1.000000 std:0.105045
# column:216 min:0.000000 max:1.000000 std:0.084181
# column:217 min:0.000000 max:1.000000 std:0.134125
# column:218 min:0.000000 max:1.000000 std:0.141407
# column:219 min:0.000000 max:1.000000 std:0.049971
# column:220 min:0.000000 max:1.000000 std:0.173294
# column:221 min:0.000000 max:1.000000 std:0.085543
# column:222 min:0.000000 max:1.000000 std:0.129026
# column:223 min:0.000000 max:1.000000 std:0.077535
# column:224 min:0.000000 max:1.000000 std:0.048724
# column:225 min:0.000000 max:1.000000 std:0.108351
# column:226 min:0.000000 max:1.000000 std:0.082463
# column:227 min:0.000000 max:1.000000 std:0.048853
# column:228 min:0.000000 max:1.000000 std:0.059246
# column:229 min:0.000000 max:1.000000 std:0.083433
# column:230 min:0.000000 max:1.000000 std:0.124082
# column:231 min:0.000000 max:1.000000 std:0.117280
# column:232 min:0.000000 max:1.000000 std:0.135878
# column:233 min:0.000000 max:1.000000 std:0.065142
# column:234 min:0.000000 max:1.000000 std:0.054531
# column:235 min:0.000000 max:1.000000 std:0.087799
# column:236 min:0.000000 max:1.000000 std:0.110415
# column:237 min:0.000000 max:1.000000 std:0.077860
# column:238 min:0.000000 max:1.000000 std:0.121751
# column:239 min:0.000000 max:1.000000 std:0.078401
# column:240 min:0.000000 max:1.000000 std:0.103657
# column:241 min:0.000000 max:1.000000 std:0.185700
# column:242 min:0.000000 max:1.000000 std:0.145842
# column:243 min:0.000000 max:1.000000 std:0.055710
# column:244 min:0.000000 max:1.000000 std:0.047162
# column:245 min:0.000000 max:1.000000 std:0.097925
# column:246 min:0.000000 max:1.000000 std:0.097631
# column:247 min:0.000000 max:1.000000 std:0.078768
# column:248 min:0.000000 max:1.000000 std:0.131412
# column:249 min:0.000000 max:1.000000 std:0.078639
# column:250 min:0.000000 max:1.000000 std:0.086108
# column:251 min:0.000000 max:1.000000 std:0.162386
# column:252 min:0.000000 max:1.000000 std:0.117852
# column:253 min:0.000000 max:1.000000 std:0.069408
# column:254 min:0.000000 max:1.000000 std:0.051373
# column:255 min:0.000000 max:1.000000 std:0.078976
# column:256 min:0.000000 max:1.000000 std:0.101978
# column:257 min:0.000000 max:1.000000 std:0.109759
# column:258 min:0.000000 max:1.000000 std:0.099865
# column:259 min:0.000000 max:1.000000 std:0.082233
# column:260 min:0.000000 max:1.000000 std:0.069815
# column:261 min:0.000000 max:1.000000 std:0.162317
# column:262 min:0.000000 max:1.000000 std:0.092451
# column:263 min:0.000000 max:1.000000 std:0.047518
# column:264 min:0.000000 max:0.000000 std:0.000000
# column:265 min:0.000000 max:1.000000 std:0.100037
# column:266 min:0.000000 max:1.000000 std:0.128293
# column:267 min:0.000000 max:1.000000 std:0.118267
# column:268 min:0.000000 max:1.000000 std:0.127387
# column:269 min:0.000000 max:1.000000 std:0.072636
# column:270 min:0.000000 max:1.000000 std:0.133724
# column:271 min:0.000000 max:1.000000 std:0.146992
# column:272 min:0.000000 max:1.000000 std:0.069938
# column:273 min:0.000000 max:1.000000 std:0.062578
# column:274 min:0.000000 max:0.000000 std:0.000000
# column:275 min:0.000000 max:1.000000 std:0.108483
# column:276 min:0.000000 max:1.000000 std:0.118706
# column:277 min:0.000000 max:1.000000 std:0.101421
# column:278 min:0.000000 max:1.000000 std:0.119569

# %% [markdown]
# ### One hot encoding of required columns

# %%
### obtain one hot encoding

df_data = pd.get_dummies(df_data, columns=cols_toOneHot)

# %% [markdown]
# - Check the resulting dataset

# %%
df_data.head()
# Out:
#             a    b         c         d         e         f         g  \
# 78   0.674699  1.0  0.088889  0.394118  0.263158  0.280534  0.563177
# 139  0.614458  1.0  0.081481  0.435294  0.225564  0.318702  0.444043
# 43   0.409639  1.0  0.088889  0.323529  0.218045  0.290076  0.545126
# 290  0.722892  1.0  0.078519  0.405882  0.270677  0.261450  0.559567
# 55   0.867470  1.0  0.081481  0.376471  0.165414  0.270992  0.577617
#
#             h         i         j      ...             jl        jm   jn   jo  \
# 78   0.256410  0.448780  0.762463      ...       0.627119  0.916084  0.0  0.0
# 139  0.157509  0.619512  0.609971      ...       0.271186  0.954545  0.0  0.0
# 43   0.131868  0.346341  0.677419      ...       0.690678  1.000000  0.0  0.0
# 290  0.293040  0.473171  0.457478      ...       0.296610  0.912587  0.0  0.0
# 55   0.190476  0.429268  0.592375      ...       0.381356  1.000000  0.0  0.0
#
#           jp        jq        jr        js  label_anomaly  label_normal
# 78   0.68750  0.700000  0.533835  0.581230              0             1
# 139  0.43750  0.625000  0.422556  0.405178              0             1
# 43   0.37500  0.408333  0.617293  0.392880              0             1
# 290  0.31250  0.525000  0.430827  0.346278              0             1
# 55   0.40625  0.716667  0.535338  0.552104              0             1
#
# [5 rows x 281 columns]

# %%
### shape is correct

df_data.shape
# Out:
# (452, 281)

# %%
df_data.describe()
# Out:
#                 a           b           c           d           e           f  \
# count  452.000000  452.000000  452.000000  452.000000  452.000000  452.000000
# mean     0.559894    0.550885    0.090649    0.365708    0.255040    0.296093
# std      0.198393    0.497955    0.055067    0.097593    0.115522    0.085577
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.433735    0.000000    0.081481    0.311765    0.187970    0.270992
# 50%      0.566265    1.000000    0.087407    0.364706    0.233083    0.299618
# 75%      0.698795    1.000000    0.096296    0.429412    0.293233    0.333969
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                 g           h           i           j      ...       \
# count  452.000000  452.000000  452.000000  452.000000      ...
# mean     0.488115    0.226920    0.439046    0.603158      ...
# std      0.120525    0.130524    0.125984    0.133230      ...
# min      0.000000    0.000000    0.000000    0.000000      ...
# 25%      0.425993    0.146520    0.385366    0.515396      ...
# 50%      0.487365    0.197802    0.443902    0.621701      ...
# 75%      0.548736    0.260073    0.497561    0.697947      ...
# max      1.000000    1.000000    1.000000    1.000000      ...
#
#                jl          jm          jn     jo          jp          jq  \
# count  452.000000  452.000000  452.000000  452.0  452.000000  452.000000
# mean     0.383390    0.949045    0.004978    0.0    0.410882    0.601862
# std      0.147155    0.070015    0.062648    0.0    0.108603    0.118838
# min      0.000000    0.000000    0.000000    0.0    0.000000    0.000000
# 25%      0.279661    0.926573    0.000000    0.0    0.375000    0.541667
# 50%      0.372881    0.961538    0.000000    0.0    0.406250    0.612500
# 75%      0.474576    1.000000    0.000000    0.0    0.468750    0.675000
# max      1.000000    1.000000    1.000000    0.0    1.000000    1.000000
#
#                jr          js  label_anomaly  label_normal
# count  452.000000  452.000000     452.000000    452.000000
# mean     0.477640    0.440603       0.146018      0.853982
# std      0.101533    0.119702       0.353515      0.353515
# min      0.000000    0.000000       0.000000      0.000000
# 25%      0.418421    0.363430       0.000000      1.000000
# 50%      0.468421    0.430421       0.000000      1.000000
# 75%      0.526504    0.516019       0.000000      1.000000
# max      1.000000    1.000000       1.000000      1.000000
#
# [8 rows x 281 columns]

# %%
### check again

checkStats(df_data)
# Out:
# column:0 min:0.000000 max:1.000000 std:0.198174
# column:1 min:0.000000 max:1.000000 std:0.497404
# column:2 min:0.000000 max:1.000000 std:0.055006
# column:3 min:0.000000 max:1.000000 std:0.097485
# column:4 min:0.000000 max:1.000000 std:0.115394
# column:5 min:0.000000 max:1.000000 std:0.085482
# column:6 min:0.000000 max:1.000000 std:0.120392
# column:7 min:0.000000 max:1.000000 std:0.130380
# column:8 min:0.000000 max:1.000000 std:0.125844
# column:9 min:0.000000 max:1.000000 std:0.133083
# column:10 min:0.000000 max:1.000000 std:0.161453
# column:11 min:0.000000 max:1.000000 std:0.088052
# column:12 min:0.000000 max:1.000000 std:0.119543
# column:13 min:0.000000 max:1.000000 std:0.145858
# column:14 min:0.000000 max:1.000000 std:0.087579
# column:15 min:0.000000 max:1.000000 std:0.120889
# column:16 min:0.000000 max:1.000000 std:0.116857
# column:17 min:0.000000 max:1.000000 std:0.233170
# column:18 min:0.000000 max:1.000000 std:0.065323
# column:19 min:0.000000 max:0.000000 std:0.000000
# column:20 min:0.000000 max:1.000000 std:0.100353
# column:21 min:0.000000 max:1.000000 std:0.046984
# column:22 min:0.000000 max:1.000000 std:0.104592
# column:23 min:0.000000 max:1.000000 std:0.104592
# column:24 min:0.000000 max:1.000000 std:0.066372
# column:25 min:0.000000 max:1.000000 std:0.066372
# column:26 min:0.000000 max:1.000000 std:0.093655
# column:27 min:0.000000 max:1.000000 std:0.147477
# column:28 min:0.000000 max:1.000000 std:0.130524
# column:29 min:0.000000 max:1.000000 std:0.228671
# column:30 min:0.000000 max:1.000000 std:0.085826
# column:31 min:0.000000 max:1.000000 std:0.048029
# column:32 min:0.000000 max:1.000000 std:0.126504
# column:33 min:0.000000 max:1.000000 std:0.131855
# column:34 min:0.000000 max:1.000000 std:0.167134
# column:35 min:0.000000 max:1.000000 std:0.046984
# column:36 min:0.000000 max:1.000000 std:0.066372
# column:37 min:0.000000 max:1.000000 std:0.066372
# column:38 min:0.000000 max:1.000000 std:0.123478
# column:39 min:0.000000 max:1.000000 std:0.237850
# column:40 min:0.000000 max:1.000000 std:0.198969
# column:41 min:0.000000 max:1.000000 std:0.191950
# column:42 min:0.000000 max:1.000000 std:0.143791
# column:43 min:0.000000 max:1.000000 std:0.070927
# column:44 min:0.000000 max:1.000000 std:0.199343
# column:45 min:0.000000 max:1.000000 std:0.046984
# column:46 min:0.000000 max:1.000000 std:0.184784
# column:47 min:0.000000 max:1.000000 std:0.046984
# column:48 min:0.000000 max:1.000000 std:0.131855
# column:49 min:0.000000 max:1.000000 std:0.104592
# column:50 min:0.000000 max:1.000000 std:0.066372
# column:51 min:0.000000 max:1.000000 std:0.182251
# column:52 min:0.000000 max:1.000000 std:0.217121
# column:53 min:0.000000 max:1.000000 std:0.229320
# column:54 min:0.000000 max:1.000000 std:0.122718
# column:55 min:0.000000 max:1.000000 std:0.046984
# column:56 min:0.000000 max:1.000000 std:0.303455
# column:57 min:0.000000 max:1.000000 std:0.104592
# column:58 min:0.000000 max:1.000000 std:0.066372
# column:59 min:0.000000 max:1.000000 std:0.066372
# column:60 min:0.000000 max:1.000000 std:0.066372
# column:61 min:0.000000 max:1.000000 std:0.066372
# column:62 min:0.000000 max:1.000000 std:0.093655
# column:63 min:0.000000 max:1.000000 std:0.195213
# column:64 min:0.000000 max:1.000000 std:0.152745
# column:65 min:0.000000 max:1.000000 std:0.249724
# column:66 min:0.000000 max:1.000000 std:0.119213
# column:67 min:0.000000 max:0.000000 std:0.000000
# column:68 min:0.000000 max:1.000000 std:0.161246
# column:69 min:0.000000 max:0.000000 std:0.000000
# column:70 min:0.000000 max:1.000000 std:0.131855
# column:71 min:0.000000 max:1.000000 std:0.046984
# column:72 min:0.000000 max:1.000000 std:0.046984
# column:73 min:0.000000 max:1.000000 std:0.081198
# column:74 min:0.000000 max:1.000000 std:0.046984
# column:75 min:0.000000 max:1.000000 std:0.174340
# column:76 min:0.000000 max:1.000000 std:0.157697
# column:77 min:0.000000 max:1.000000 std:0.193057
# column:78 min:0.000000 max:1.000000 std:0.106150
# column:79 min:0.000000 max:1.000000 std:0.063368
# column:80 min:0.000000 max:1.000000 std:0.162675
# column:81 min:0.000000 max:1.000000 std:0.066372
# column:82 min:0.000000 max:1.000000 std:0.154091
# column:83 min:0.000000 max:0.000000 std:0.000000
# column:84 min:0.000000 max:1.000000 std:0.046984
# column:85 min:0.000000 max:1.000000 std:0.046984
# column:86 min:0.000000 max:1.000000 std:0.046984
# column:87 min:0.000000 max:1.000000 std:0.191417
# column:88 min:0.000000 max:1.000000 std:0.075922
# column:89 min:0.000000 max:1.000000 std:0.205510
# column:90 min:0.000000 max:1.000000 std:0.157079
# column:91 min:0.000000 max:1.000000 std:0.054847
# column:92 min:0.000000 max:1.000000 std:0.165072
# column:93 min:0.000000 max:1.000000 std:0.081198
# column:94 min:0.000000 max:1.000000 std:0.123478
# column:95 min:0.000000 max:1.000000 std:0.093655
# column:96 min:0.000000 max:1.000000 std:0.093655
# column:97 min:0.000000 max:1.000000 std:0.104592
# column:98 min:0.000000 max:1.000000 std:0.147086
# column:99 min:0.000000 max:1.000000 std:0.158795
# column:100 min:0.000000 max:1.000000 std:0.075256
# column:101 min:0.000000 max:1.000000 std:0.162076
# column:102 min:0.000000 max:1.000000 std:0.116363
# column:103 min:0.000000 max:1.000000 std:0.070337
# column:104 min:0.000000 max:1.000000 std:0.136175
# column:105 min:0.000000 max:1.000000 std:0.093655
# column:106 min:0.000000 max:1.000000 std:0.093655
# column:107 min:0.000000 max:1.000000 std:0.114447
# column:108 min:0.000000 max:1.000000 std:0.093655
# column:109 min:0.000000 max:1.000000 std:0.093655
# column:110 min:0.000000 max:1.000000 std:0.131855
# column:111 min:0.000000 max:1.000000 std:0.169863
# column:112 min:0.000000 max:1.000000 std:0.102773
# column:113 min:0.000000 max:1.000000 std:0.146486
# column:114 min:0.000000 max:1.000000 std:0.069085
# column:115 min:0.000000 max:1.000000 std:0.056410
# column:116 min:0.000000 max:1.000000 std:0.115214
# column:117 min:0.000000 max:1.000000 std:0.154091
# column:118 min:0.000000 max:1.000000 std:0.066372
# column:119 min:0.000000 max:1.000000 std:0.081198
# column:120 min:0.000000 max:1.000000 std:0.093655
# column:121 min:0.000000 max:1.000000 std:0.081198
# column:122 min:0.000000 max:1.000000 std:0.104592
# column:123 min:0.000000 max:1.000000 std:0.130884
# column:124 min:0.000000 max:1.000000 std:0.112734
# column:125 min:0.000000 max:1.000000 std:0.136557
# column:126 min:0.000000 max:1.000000 std:0.123777
# column:127 min:0.000000 max:1.000000 std:0.050565
# column:128 min:0.000000 max:1.000000 std:0.129449
# column:129 min:0.000000 max:1.000000 std:0.066372
# column:130 min:0.000000 max:1.000000 std:0.114447
# column:131 min:0.000000 max:0.000000 std:0.000000
# column:132 min:0.000000 max:0.000000 std:0.000000
# column:133 min:0.000000 max:1.000000 std:0.066372
# column:134 min:0.000000 max:1.000000 std:0.131855
# column:135 min:0.000000 max:1.000000 std:0.122253
# column:136 min:0.000000 max:1.000000 std:0.088122
# column:137 min:0.000000 max:1.000000 std:0.144090
# column:138 min:0.000000 max:1.000000 std:0.053925
# column:139 min:0.000000 max:0.000000 std:0.000000
# column:140 min:0.000000 max:1.000000 std:0.079179
# column:141 min:0.000000 max:0.000000 std:0.000000
# column:142 min:0.000000 max:1.000000 std:0.081198
# column:143 min:0.000000 max:0.000000 std:0.000000
# column:144 min:0.000000 max:1.000000 std:0.046984
# column:145 min:0.000000 max:0.000000 std:0.000000
# column:146 min:0.000000 max:1.000000 std:0.081198
# column:147 min:0.000000 max:1.000000 std:0.125915
# column:148 min:0.000000 max:1.000000 std:0.101344
# column:149 min:0.000000 max:1.000000 std:0.206260
# column:150 min:0.000000 max:1.000000 std:0.066641
# column:151 min:0.000000 max:0.000000 std:0.000000
# column:152 min:0.000000 max:1.000000 std:0.098660
# column:153 min:0.000000 max:1.000000 std:0.046984
# column:154 min:0.000000 max:1.000000 std:0.046984
# column:155 min:0.000000 max:1.000000 std:0.066372
# column:156 min:0.000000 max:0.000000 std:0.000000
# column:157 min:0.000000 max:0.000000 std:0.000000
# column:158 min:0.000000 max:1.000000 std:0.104592
# column:159 min:0.000000 max:1.000000 std:0.059962
# column:160 min:0.000000 max:1.000000 std:0.146663
# column:161 min:0.000000 max:1.000000 std:0.140712
# column:162 min:0.000000 max:1.000000 std:0.107303
# column:163 min:0.000000 max:1.000000 std:0.049935
# column:164 min:0.000000 max:0.000000 std:0.000000
# column:165 min:0.000000 max:1.000000 std:0.108319
# column:166 min:0.000000 max:1.000000 std:0.097738
# column:167 min:0.000000 max:1.000000 std:0.069911
# column:168 min:0.000000 max:1.000000 std:0.117955
# column:169 min:0.000000 max:1.000000 std:0.090173
# column:170 min:0.000000 max:1.000000 std:0.163412
# column:171 min:0.000000 max:1.000000 std:0.181586
# column:172 min:0.000000 max:1.000000 std:0.109639
# column:173 min:0.000000 max:1.000000 std:0.055015
# column:174 min:0.000000 max:1.000000 std:0.060104
# column:175 min:0.000000 max:1.000000 std:0.112800
# column:176 min:0.000000 max:1.000000 std:0.115570
# column:177 min:0.000000 max:1.000000 std:0.132795
# column:178 min:0.000000 max:1.000000 std:0.146885
# column:179 min:0.000000 max:1.000000 std:0.080392
# column:180 min:0.000000 max:1.000000 std:0.116325
# column:181 min:0.000000 max:1.000000 std:0.158770
# column:182 min:0.000000 max:1.000000 std:0.174838
# column:183 min:0.000000 max:1.000000 std:0.058918
# column:184 min:0.000000 max:1.000000 std:0.076478
# column:185 min:0.000000 max:1.000000 std:0.109247
# column:186 min:0.000000 max:1.000000 std:0.083281
# column:187 min:0.000000 max:1.000000 std:0.118544
# column:188 min:0.000000 max:1.000000 std:0.118958
# column:189 min:0.000000 max:1.000000 std:0.062836
# column:190 min:0.000000 max:1.000000 std:0.190221
# column:191 min:0.000000 max:1.000000 std:0.099552
# column:192 min:0.000000 max:1.000000 std:0.218447
# column:193 min:0.000000 max:1.000000 std:0.125209
# column:194 min:0.000000 max:1.000000 std:0.046984
# column:195 min:0.000000 max:1.000000 std:0.109155
# column:196 min:0.000000 max:1.000000 std:0.108200
# column:197 min:0.000000 max:1.000000 std:0.088576
# column:198 min:0.000000 max:1.000000 std:0.136832
# column:199 min:0.000000 max:1.000000 std:0.055572
# column:200 min:0.000000 max:1.000000 std:0.113901
# column:201 min:0.000000 max:1.000000 std:0.183748
# column:202 min:0.000000 max:1.000000 std:0.149978
# column:203 min:0.000000 max:1.000000 std:0.084153
# column:204 min:0.000000 max:0.000000 std:0.000000
# column:205 min:0.000000 max:1.000000 std:0.120664
# column:206 min:0.000000 max:1.000000 std:0.081437
# column:207 min:0.000000 max:1.000000 std:0.085369
# column:208 min:0.000000 max:1.000000 std:0.143769
# column:209 min:0.000000 max:1.000000 std:0.106426
# column:210 min:0.000000 max:1.000000 std:0.135494
# column:211 min:0.000000 max:1.000000 std:0.176704
# column:212 min:0.000000 max:1.000000 std:0.133115
# column:213 min:0.000000 max:1.000000 std:0.053718
# column:214 min:0.000000 max:1.000000 std:0.058927
# column:215 min:0.000000 max:1.000000 std:0.105045
# column:216 min:0.000000 max:1.000000 std:0.084181
# column:217 min:0.000000 max:1.000000 std:0.134125
# column:218 min:0.000000 max:1.000000 std:0.141407
# column:219 min:0.000000 max:1.000000 std:0.049971
# column:220 min:0.000000 max:1.000000 std:0.173294
# column:221 min:0.000000 max:1.000000 std:0.085543
# column:222 min:0.000000 max:1.000000 std:0.129026
# column:223 min:0.000000 max:1.000000 std:0.077535
# column:224 min:0.000000 max:1.000000 std:0.048724
# column:225 min:0.000000 max:1.000000 std:0.108351
# column:226 min:0.000000 max:1.000000 std:0.082463
# column:227 min:0.000000 max:1.000000 std:0.048853
# column:228 min:0.000000 max:1.000000 std:0.059246
# column:229 min:0.000000 max:1.000000 std:0.083433
# column:230 min:0.000000 max:1.000000 std:0.124082
# column:231 min:0.000000 max:1.000000 std:0.117280
# column:232 min:0.000000 max:1.000000 std:0.135878
# column:233 min:0.000000 max:1.000000 std:0.065142
# column:234 min:0.000000 max:1.000000 std:0.054531
# column:235 min:0.000000 max:1.000000 std:0.087799
# column:236 min:0.000000 max:1.000000 std:0.110415
# column:237 min:0.000000 max:1.000000 std:0.077860
# column:238 min:0.000000 max:1.000000 std:0.121751
# column:239 min:0.000000 max:1.000000 std:0.078401
# column:240 min:0.000000 max:1.000000 std:0.103657
# column:241 min:0.000000 max:1.000000 std:0.185700
# column:242 min:0.000000 max:1.000000 std:0.145842
# column:243 min:0.000000 max:1.000000 std:0.055710
# column:244 min:0.000000 max:1.000000 std:0.047162
# column:245 min:0.000000 max:1.000000 std:0.097925
# column:246 min:0.000000 max:1.000000 std:0.097631
# column:247 min:0.000000 max:1.000000 std:0.078768
# column:248 min:0.000000 max:1.000000 std:0.131412
# column:249 min:0.000000 max:1.000000 std:0.078639
# column:250 min:0.000000 max:1.000000 std:0.086108
# column:251 min:0.000000 max:1.000000 std:0.162386
# column:252 min:0.000000 max:1.000000 std:0.117852
# column:253 min:0.000000 max:1.000000 std:0.069408
# column:254 min:0.000000 max:1.000000 std:0.051373
# column:255 min:0.000000 max:1.000000 std:0.078976
# column:256 min:0.000000 max:1.000000 std:0.101978
# column:257 min:0.000000 max:1.000000 std:0.109759
# column:258 min:0.000000 max:1.000000 std:0.099865
# column:259 min:0.000000 max:1.000000 std:0.082233
# column:260 min:0.000000 max:1.000000 std:0.069815
# column:261 min:0.000000 max:1.000000 std:0.162317
# column:262 min:0.000000 max:1.000000 std:0.092451
# column:263 min:0.000000 max:1.000000 std:0.047518
# column:264 min:0.000000 max:0.000000 std:0.000000
# column:265 min:0.000000 max:1.000000 std:0.100037
# column:266 min:0.000000 max:1.000000 std:0.128293
# column:267 min:0.000000 max:1.000000 std:0.118267
# column:268 min:0.000000 max:1.000000 std:0.127387
# column:269 min:0.000000 max:1.000000 std:0.072636
# column:270 min:0.000000 max:1.000000 std:0.133724
# column:271 min:0.000000 max:1.000000 std:0.146992
# column:272 min:0.000000 max:1.000000 std:0.069938
# column:273 min:0.000000 max:1.000000 std:0.062578
# column:274 min:0.000000 max:0.000000 std:0.000000
# column:275 min:0.000000 max:1.000000 std:0.108483
# column:276 min:0.000000 max:1.000000 std:0.118706
# column:277 min:0.000000 max:1.000000 std:0.101421
# column:278 min:0.000000 max:1.000000 std:0.119569
# column:279 min:0.000000 max:1.000000 std:0.353124
# column:280 min:0.000000 max:1.000000 std:0.353124

# %%
## check integrity of the data again

print(df_data.isnull().values.any())

print(df_data.isna().values.any())
# Out:
# False
# False

# %%
### check again
print(df_data.iloc[140:150, -1])

print(df_data.iloc[140:150, -2])

print(df_labels.iloc[140:150, -1])
# Out:
# 285    0
# 390    1
# 7      1
# 99     1
# 328    1
# 251    0
# 402    1
# 292    1
# 73     1
# 120    1
# Name: label_normal, dtype: uint8
# 285    1
# 390    0
# 7      0
# 99     0
# 328    0
# 251    1
# 402    0
# 292    0
# 73     0
# 120    0
# Name: label_anomaly, dtype: uint8
# 285    3
# 390    1
# 7      1
# 99     1
# 328    1
# 251    4
# 402    1
# 292    1
# 73     1
# 120    1
# Name: labels, dtype: object

# %% [markdown]
# ### Save dataset

# %%
dataset = df_data.values

# %%
dataset.shape
# Out:
# (452, 281)

# %%
np.savez_compressed("../../datasets/arythmia/arythmia.npz", dataset=dataset)

# %% [markdown]
# ### Produce train and test splits

# %%
random_state = None

# %%
from sklearn.model_selection import train_test_split

x_train, x_test = train_test_split(dataset, test_size=0.5, random_state=random_state)

# %%
x_train.shape
# Out:
# (226, 281)

# %%
x_test.shape
# Out:
# (226, 281)

# %% [markdown]
# -  Normal class is anomaly (attack) in this case, because non-attack rows are minority

# %%
x_train_normal = x_train[np.where(x_train[:,-1] == 1)]   ##last column is the normal column
x_train_anomaly = x_train[np.where(x_train[:,-1] == 0)]

# %%
x_train_normal.shape
# Out:
# (198, 281)

# %%
x_train_anomaly.shape
# Out:
# (28, 281)

# %%
x_train = x_train_normal

# %% [markdown]
# - x_train consist of "normal" values

# %%
x_train.shape
# Out:
# (198, 281)

# %%
x_test.shape
# Out:
# (226, 281)

# %% [markdown]
# - Assign arbitrary output as labels

# %%
y_train = np.zeros((len(x_train),2))
y_train[:,0] = 1
y_train.shape
# Out:
# (198, 2)

# %%
train_name = "../../datasets/arythmia/arythmia_train-randomState_"+str(random_state)+".npz"
test_name = "../../datasets/arythmia/arythmia_test-randomState_"+str(random_state)+".npz"

np.savez_compressed(train_name, x_train=x_train, y_train=y_train)
np.savez_compressed(test_name, x_test=x_test)
